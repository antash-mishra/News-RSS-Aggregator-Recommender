# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
import csv

# %%
news = pd.read_table('news.tsv',
                     header=None,
                     usecols=[0, 3, 4],
                     quoting=csv.QUOTE_NONE,
                     names=[
                       'id', 'title','abstract'
                     ])

# %%
news.head()
# Out:
#        id                                              title  \
# 0  N55528  The Brands Queen Elizabeth, Prince Charles, an...
# 1  N19639                      50 Worst Habits For Belly Fat
# 2  N61837  The Cost of Trump's Aid Freeze in the Trenches...
# 3  N53526  I Was An NBA Wife. Here's How It Affected My M...
# 4  N38324  How to Get Rid of Skin Tags, According to a De...
#
#                                             abstract
# 0  Shop the notebooks, jackets, and more that the...
# 1  These seemingly harmless habits are holding yo...
# 2  Lt. Ivan Molchanets peeked over a parapet of s...
# 3  I felt like I was a fraud, and being an NBA wi...
# 4  They seem harmless, but there's a very good re...

# %%
behaviors = pd.read_table(
    'behaviors.tsv',
    header=None,
    names=['impression_id', 'user', 'time', 'clicked_news', 'impressions'])

# %%
behaviors.clicked_news.fillna(' ', inplace=True)
behaviors.impressions = behaviors.impressions.str.split()

# %%
# behavior_user_example = behaviors[behaviors['user'] == 'U13740']
behavior_user_example = behaviors.copy()

# %%
behavior_user_example.head()
# Out:
#    impression_id    user                   time  \
# 0              1  U13740  11/11/2019 9:05:58 AM
# 1              2  U91836  11/12/2019 6:11:30 PM
# 2              3  U73700  11/14/2019 7:01:48 AM
# 3              4  U34670  11/11/2019 5:28:05 AM
# 4              5   U8125  11/12/2019 4:11:21 PM
#
#                                         clicked_news  \
# 0  N55189 N42782 N34694 N45794 N18445 N63302 N104...
# 1  N31739 N6072 N63045 N23979 N35656 N43353 N8129...
# 2  N10732 N25792 N7563 N21087 N41087 N5445 N60384...
# 3  N45729 N2203 N871 N53880 N41375 N43142 N33013 ...
# 4                        N10078 N56514 N14904 N33740
#
#                                          impressions
# 0                               [N55689-1, N35729-0]
# 1  [N20678-0, N39317-0, N58114-0, N20495-0, N4297...
# 2  [N50014-0, N23877-0, N35389-0, N49712-0, N1684...
# 3           [N35729-0, N33632-0, N49685-1, N27581-0]
# 4  [N39985-0, N36050-0, N16096-0, N8400-1, N22407...

# %%
behavior_user_example['clicked_news'] = behavior_user_example['clicked_news'].str.split()

# %%
behavior_user_example_new = behavior_user_example.copy()

# %%
behavior_user_example_new['combined'] = behavior_user_example.apply(lambda row: row['clicked_news'] + row['impressions'], axis=1)
behavior_user_example_new = behavior_user_example_new.drop(columns=['clicked_news', 'impressions'])

# %%
behavior_user_example_new
# Out:
#           user clicked_news clicked_value
# 0       U13740       N55189             1
# 0       U13740       N42782             1
# 0       U13740       N34694             1
# 0       U13740       N45794             1
# 0       U13740       N18445             1
# ...        ...          ...           ...
# 156963  U44625       N39317             0
# 156964  U64800       N61233             0
# 156964  U64800       N33828             1
# 156964  U64800       N19661             0
# 156964  U64800       N41934             0
#
# [5948886 rows x 3 columns]

# %%
behavior_user_example_new = behavior_user_example_new.explode('combined')

# %%
def get_left_of_hyphen(s):
    parts = s.split("-")
    return parts[0] if len(parts) > 1 else s

# %%
def get_right_of_hyphen(s):
    parts = s.split("-")
    return parts[1] if len(parts) > 1 else 1

# %%
behavior_user_example_new['clicked_news'] = behavior_user_example_new['combined'].apply(get_left_of_hyphen)

# %%
behavior_user_example_new['clicked_value'] = behavior_user_example_new['combined'].apply(get_right_of_hyphen)

# %%
behavior_user_example_new = behavior_user_example_new.drop(columns=['impression_id', 'time'])

# %%
behavior_user_example_new = behavior_user_example_new.drop(columns=['combined'])

# %%
behavior_user_example_new = behavior_user_example_new.drop_duplicates()

# %%
news[news['clicked_news'] == 'N45794']
# Out:
# Empty DataFrame
# Columns: [clicked_news, title, abstract]
# Index: []

# %%
news.rename(columns = {'id':'clicked_news'}, inplace = True)

# %%
behavior_merged = behavior_user_example_new.merge(news[['clicked_news','title', 'abstract']], on = 'clicked_news', how = 'inner')

# %%
behavior_merged.describe()
# Out:
#            user clicked_news clicked_value  \
# count   5706634      5706634       5706634
# unique    50000        48616             3
# top      U63482       N47061             0
# freq       1440        16575       4594666
#
#                                                     title  \
# count                                             5706634
# unique                                              47799
# top     105 Black Friday Deals You Can Start Shopping ...
# freq                                                16575
#
#                                                  abstract
# count                                             5706634
# unique                                              47309
# top     Save with early bird deals from stores like Wa...
# freq                                                16575

# %%
behavior_merged = behavior_merged.dropna()

# %%
behavior_merged[behavior_merged['clicked_value'] == '0']
# Out:
#           user clicked_news clicked_value  \
# 3871    U45632       N63302             0
# 4231    U84229       N63302             0
# 4305    U36488       N63302             0
# 4319    U18021       N63302             0
# 19063   U38751       N35458             0
# ...        ...          ...           ...
# 943644  U65895       N62092             0
# 943655  U69085       N13934             0
# 943764  U54826        N8075             0
# 943811  U16965       N54013             0
# 943905  U20662       N15844             0
#
#                                                     title  \
# 3871    This Wedding Photo of a Canine Best Man Captur...
# 4231    This Wedding Photo of a Canine Best Man Captur...
# 4305    This Wedding Photo of a Canine Best Man Captur...
# 4319    This Wedding Photo of a Canine Best Man Captur...
# 19063   Brazil oil auction a 'total disaster' as bidde...
# ...                                                   ...
# 943644  Marvel's Avengers game release date, news, tra...
# 943655     Things to do around Port Huron | November 2019
# 943764  Black Friday: The Best Deals on Kids' Toys and...
# 943811  This Louisville woman's tea shop will be an LG...
# 943905  AirPods Pro Sale: Save on Apple's latest true ...
#
#                                                  abstract
# 3871    When Mark Doublet made his dog, Marley, the be...
# 4231    When Mark Doublet made his dog, Marley, the be...
# 4305    When Mark Doublet made his dog, Marley, the be...
# 4319    When Mark Doublet made his dog, Marley, the be...
# 19063   Brazil's largest-ever auction of oil deposits ...
# ...                                                   ...
# 943644  After two years of secrecy, we've finally seen...
# 943655  Community events happening around Port Huron i...
# 943764  From Legos to Frozen 2 merch, we've got you co...
# 943811  Arielle Clark, a 28-year-old queer woman and L...
# 943905  Editor's Note: This sale went fast, as we expe...
#
# [414160 rows x 5 columns]

# %%
behavior_merged['combined'] = behavior_merged['title'] + ' ' + behavior_merged['abstract']

# %%
behavior_merged.to_csv('main.csv', header=True)

# %% [markdown]
# ## Recommendation System

# %%
import pandas as pd

behavior_merged = pd.read_csv('drive/MyDrive/main.csv')

# %%
behavior_merged.head()
# Out:
#    Unnamed: 0    user clicked_news  clicked_value  \
# 0           0  U13740       N55189              1
# 1           1  U10045       N55189              1
# 2           2  U85394       N55189              1
# 3           3  U78244       N55189              1
# 4           4  U27024       N55189              1
#
#                                                title  \
# 0  'Wheel Of Fortune' Guest Delivers Hilarious, O...
# 1  'Wheel Of Fortune' Guest Delivers Hilarious, O...
# 2  'Wheel Of Fortune' Guest Delivers Hilarious, O...
# 3  'Wheel Of Fortune' Guest Delivers Hilarious, O...
# 4  'Wheel Of Fortune' Guest Delivers Hilarious, O...
#
#                                             abstract  \
# 0  We'd like to solve the puzzle, Pat: Blair Davi...
# 1  We'd like to solve the puzzle, Pat: Blair Davi...
# 2  We'd like to solve the puzzle, Pat: Blair Davi...
# 3  We'd like to solve the puzzle, Pat: Blair Davi...
# 4  We'd like to solve the puzzle, Pat: Blair Davi...
#
#                                             combined
# 0  'Wheel Of Fortune' Guest Delivers Hilarious, O...
# 1  'Wheel Of Fortune' Guest Delivers Hilarious, O...
# 2  'Wheel Of Fortune' Guest Delivers Hilarious, O...
# 3  'Wheel Of Fortune' Guest Delivers Hilarious, O...
# 4  'Wheel Of Fortune' Guest Delivers Hilarious, O...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import pairwise_distances
import heapq

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string
import re
import spacy

# Download NLTK resources
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

def preprocess_text(text):
    # Tokenization
    tokens = word_tokenize(text)

    # Lowercasing
    tokens = [token.lower() for token in tokens]

    # Remove punctuation
    tokens = [token for token in tokens if token not in string.punctuation]

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]

    # Lemmatization using NLTK
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # Remove non-alphabetic characters
    tokens = [re.sub(r'[^a-zA-Z]', '', token) for token in tokens]

    # Remove empty tokens
    tokens = [token for token in tokens if token.strip() != '']

    # Join tokens back into text
    preprocessed_text = ' '.join(tokens)

    return preprocessed_text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
behavior_merged['combined'] = behavior_merged['combined'].apply(preprocess_text)

# %%
behavior_merged.to_csv('preprocessed_data.csv', header=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-be2fc730e980> in <cell line: 1>()
# ----> 1 behavior_merged.to_csv('preprocessed_data.csv', header=True)
#
# NameError: name 'behavior_merged' is not defined

# %%
vectorizer = TfidfVectorizer(min_df = 0)

# %%
corpus = behavior_merged['combined']

# %%
tfidf_matrix = vectorizer.fit_transform(behavior_merged['combined'].values)
tfidf_matrix
# Out:
# <5706634x54746 sparse matrix of type '<class 'numpy.float64'>'
# 	with 110806712 stored elements in Compressed Sparse Row format>

# %%
tfidf_dense = tfidf_matrix.toarray()
tfidf_dense

# %%
article_similarity = pairwise_distances(tfidf_dense, metric='jaccard')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-4e6b40939211> in <cell line: 1>()
# ----> 1 article_similarity = pairwise_distances(tfidf_matrix, metric='jaccard')
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2017     else:
#    2018         if issparse(X) or issparse(Y):
# -> 2019             raise TypeError("scipy distance metrics do not support sparse matrices.")
#    2020
#    2021         dtype = bool if metric in PAIRWISE_BOOLEAN_FUNCTIONS else None
#
# TypeError: scipy distance metrics do not support sparse matrices.
